# %% [markdown]
# # Revolutionizing Football Analysis: A Deep Learning Approch to Predict the direction of Penalty in Football

# %% [markdown]
# The main aim of this project is to predict the direction of penalty shot in Football using pre-trained Deep Learning models and Image frames just before penalty shot has been taken. In this notebook InceptionV3 pre-trained deep learning model has been utilized. The images that are used for training the model has been taken out from penalty shoot videos. The images are classified into 5 categories based on the direction of the shot. The classes are Centre, Left_lower, Left_upper, Right_lower, Right_upper.
#
# In this notebook step by step implementation of this project has been depicted.

# %%
# %%capture
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ### The necessary Python library has been imported

# %%
# %%capture
import cv2
import numpy as np
import PIL.Image as Image
import seaborn as sns
import pathlib
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing the Image Dataset

# %%
data = '/kaggle/input/planet-detect/Planet_detect'
data = pathlib.Path(data)
data
# Out:
# PosixPath('/kaggle/input/planet-detect/Planet_detect')

# %% [markdown]
# ### Counting total number of images

# %%
image_count = len(list(data.glob('*/*.png')))
print(image_count)
# Out:
# 2960

# %% [markdown]
# ### Some sample Images used for this project

# %%
exo = list(data.glob('exo_zip/*'))
non_exo = list(data.glob('non_exo_zip/*'))

# %%
print(len(exo))
print(len(non_exo))
# Out:
# 1480
# 1480

# %%
import random

exo = random.sample(exo, 500)
non_exo = random.sample(non_exo, 500)
print(len(exo))
print(len(non_exo))
# Out:
# 500
# 500

# %% [markdown]
# ### Creating a dictionary data structure for storing penalty shot images based on its direction

# %%
image_dict = {
    'exo': exo,
    'non_exo': non_exo
}

# %% [markdown]
# ### Plotting Distribution of Image dataset based on Penalty shot direction

# %%
import pandas as pd
a = len(image_dict['exo'])
b = len(image_dict['non_exo'])


data = {
    'Class':['exo_planet','non_exo_planet'],
    'freq':[a,b]
}

df = pd.DataFrame(data)
# Choose a colormap for the plot
colors = sns.color_palette("viridis", n_colors=len(df))

# Plotting a horizontal bar plot with seaborn
ax = sns.barplot(x='Class', y='freq', data=df, palette=colors)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.title('Distribution of Image Dataset')
plt.show()

# %% [markdown]
# ### Labeling the Class(Penalty shot direction)

# %%
labels_dict = {
    'exo':0,
    'non_exo':1
}

# %% [markdown]
# ### Printing the Shape of the Images used

# %%
img = cv2.imread(str(image_dict['exo'][0]))

print(img.shape)
# Out:
# (462, 775, 3)

# %% [markdown]
# ### Storing the images and its corresponding labels in array data structure

# %%
X, y = [], []

for cl, images in image_dict.items():
    for image in images:
        img = cv2.imread(str(image))
        resized_img = cv2.resize(img,(224,224))
        X.append(resized_img)
        y.append(labels_dict[cl])
        
X = np.array(X)
y = np.array(y)

# %% [markdown]
# ### The Class labels has been One-hot-encoded

# %%
# Convert to one-hot encoding
num_classes = np.max(y) + 1  # Assuming class labels start from 0
y_one_hot = tf.keras.utils.to_categorical(y, num_classes=num_classes)

# %% [markdown]
# ### Splitting the Dataset into Train and Test Dataset

# %%
from sklearn.model_selection import train_test_split
# Define the split ratios
train_ratio = 0.85
test_ratio = 0.15
#validate_ratio = 0.15

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size=1 - train_ratio, random_state=42)
#X_test, X_validate, y_test, y_validate = train_test_split(X_temp, y_temp, test_size=validate_ratio / (test_ratio + validate_ratio), random_state=42)

# Verify the sizes of the sets
print("Train set size:", len(X_train))
print("Test set size:", len(X_test))
#print("Validation set size:", len(X_validate))'''
# Out:
# Train set size: 849
# Test set size: 151

# %% [markdown]
# ### Loading the Pre-trained Deep Learning Model(InceptionV3)

# %%
preprocess_input = tf.keras.applications.inception_v3.preprocess_input

# %%
base_model = tf.keras.applications.inception_v3.InceptionV3(input_shape=(224,224,3),
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step

# %%
print("Number of layers in the base model: ", len(base_model.layers))

# %% [markdown]
# ### Plotting the Feature Map of the InceptionV3 Pre-trained Model

# %%
# Access the layers attribute to get a list of layer objects
layers = base_model.layers

# Create a list to store the names of the layers
layer_names = []

# Iterate through the layers and append their names to the list
for layer in layers:
    layer_names.append(layer.name)

# %%
from tensorflow.keras.preprocessing import image
# Load and preprocess an example image
img_path = '/kaggle/input/dog-sentiment/Dog Images/Happy dog/10.jpg'   # Replace with the path to your image
img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = img_array/255
img_array = np.expand_dims(img_array, axis=0)
#img_array = preprocess_input(img_array)

# Get the feature maps from all layers
#layer_names = [layer.name for layer in model.layers if 'conv2d' in layer.name]  # Selecting Conv2D layers
outputs = [base_model.get_layer(name).output for name in layer_names]
feature_extraction_model = tf.keras.models.Model(inputs=base_model.input, outputs=outputs)


# Get the feature maps for the input image
feature_maps = feature_extraction_model(img_array)

# Display the original image
plt.figure(figsize=(6, 6))
plt.imshow(img)
plt.title('Original Image')
plt.show()

# Display one feature map for first layer
for i, feature_map in enumerate(feature_maps):
    if i==310:
        plt.figure(figsize=(8, 8))
        plt.imshow(feature_map[0, :, :, 0], cmap='viridis')  # Display the first channel of the feature map
        plt.axis('off')
        plt.title(f'Feature Map - Layer {layer_names[i]}')
        #plt.show()
        plt.savefig('temp_plot.jpeg')  
        temp_plot = Image.open('temp_plot.jpeg')
        temp_plot.save('feature_map.jpeg')
        temp_plot.close()  
        os.remove('feature_map.jpeg')

# Display one feature map for last layer
'''for i, feature_map in enumerate(feature_maps):
    if i==310:
        plt.figure(figsize=(8, 8))
        plt.imshow(feature_map[0, :, :, 0], cmap='viridis')  # Display the first channel of the feature map
        plt.axis('off')
        plt.title(f'Feature Map - Layer {layer_names[i]}')
        #plt.show()
        plt.savefig('temp_plot.jpeg')  
        temp_plot = Image.open('temp_plot.jpeg')
        temp_plot.save('feature_map_1.jpeg')
        temp_plot.close()  
        os.remove('feature_map_1.jpeg')    '''

# %% [markdown]
# ### The feature extractor converts each (224 * 224 * 3) image into a (5 * 5 * 2048) block of features

# %%
feature_batch = base_model(X_train)
print(feature_batch.shape)
# Out:
# (849, 5, 5, 2048)

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),  
  tf.keras.layers.RandomRotation(0.1),
])

# %% [markdown]
# ### Freeze the Convolutional Base
# It is important to freeze the convolutional base before compilation and training the pre-trained deep learning models. It is done so that while training the weights in a given layer do not get updated.

# %%
base_model.trainable = False

# %%
# Let's take a look at the base model architecture
#base_model.summary()

# %% [markdown]
# ### Number of layers in the model used:

# %%
print("Number of layers in the base model: ", len(base_model.layers))
# Out:
# Number of layers in the base model:  311

# %% [markdown]
# ## Adding a classification head to the model

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (849, 2048)

# %%
prediction_layer = tf.keras.layers.Dense(2,activation='sigmoid')
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (849, 2)

# %%
inputs = tf.keras.Input(shape=(224, 224, 3))
#x = tf.image.central_crop(x, central_fraction=0.5)
#x = data_augmentation(inputs)
x = preprocess_input(inputs)
x = base_model(x, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %% [markdown]
# ### Plotting the image of the Deep Learning Model used:

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ### Compiling the Deep Learning Model:

# %%
base_learning_rate = 0.0001  # Set your desired learning rate
num_classes = 2  # Set the number of classes in your problem

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
    loss='binary_crossentropy',
    metrics=['acc','Precision','Recall',
            tf.keras.metrics.AUC(multi_label=True),
             tf.keras.metrics.FalsePositives(name='fp'),
             tf.keras.metrics.FalseNegatives(name='fn'), 
             tf.keras.metrics.TruePositives(name='tp'), 
             tf.keras.metrics.TrueNegatives(name='tn')
            ]
)

# %% [markdown]
# ### Summary of the Deep Learning Model

# %%
model.summary()

# %%
#len(model.trainable_variables)

# %% [markdown]
# ### Training the Model
# Remove '%%capture' from beginning of the code to see the epochs running

# %%
from keras import callbacks 
early_stop = callbacks.EarlyStopping(
        monitor="val_acc", 
        patience=40,
        verbose=1,
        mode="max",
        restore_best_weights=True, 
     )

history = model.fit(X_train, y_train,batch_size =32, epochs=200,callbacks=[early_stop], validation_data=(X_test,y_test))

#model.save('trained_model_4.h5')
# Out:
# Epoch 1/200
# 27/27 [==============================] - 13s 201ms/step - loss: 0.7424 - acc: 0.5241 - precision: 0.5095 - recall: 0.5677 - auc: 0.5198 - fp: 464.0000 - fn: 367.0000 - tp: 482.0000 - tn: 385.0000 - val_loss: 0.7038 - val_acc: 0.5166 - val_precision: 0.5285 - val_recall: 0.4305 - val_auc: 0.5507 - val_fp: 58.0000 - val_fn: 86.0000 - val_tp: 65.0000 - val_tn: 93.0000
# Epoch 2/200
# 27/27 [==============================] - 2s 59ms/step - loss: 0.7156 - acc: 0.5689 - precision: 0.5362 - recall: 0.5065 - auc: 0.5494 - fp: 372.0000 - fn: 419.0000 - tp: 430.0000 - tn: 477.0000 - val_loss: 0.6646 - val_acc: 0.6755 - val_precision: 0.5850 - val_recall: 0.5695 - val_auc: 0.6336 - val_fp: 61.0000 - val_fn: 65.0000 - val_tp: 86.0000 - val_tn: 90.0000
# Epoch 3/200
# 27/27 [==============================] - 2s 61ms/step - loss: 0.6839 - acc: 0.6278 - precision: 0.5695 - recall: 0.5842 - auc: 0.6049 - fp: 375.0000 - fn: 353.0000 - tp: 496.0000 - tn: 474.0000 - val_loss: 0.6343 - val_acc: 0.7285 - val_precision: 0.6275 - val_recall: 0.6358 - val_auc: 0.6978 - val_fp: 57.0000 - val_fn: 55.0000 - val_tp: 96.0000 - val_tn: 94.0000
# Epoch 4/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.6581 - acc: 0.6478 - precision: 0.6128 - recall: 0.6302 - auc: 0.6547 - fp: 338.0000 - fn: 314.0000 - tp: 535.0000 - tn: 511.0000 - val_loss: 0.6125 - val_acc: 0.7285 - val_precision: 0.6824 - val_recall: 0.6689 - val_auc: 0.7516 - val_fp: 47.0000 - val_fn: 50.0000 - val_tp: 101.0000 - val_tn: 104.0000
# Epoch 5/200
# 27/27 [==============================] - 2s 58ms/step - loss: 0.6354 - acc: 0.6996 - precision: 0.6591 - recall: 0.6466 - auc: 0.7002 - fp: 284.0000 - fn: 300.0000 - tp: 549.0000 - tn: 565.0000 - val_loss: 0.5906 - val_acc: 0.7483 - val_precision: 0.7020 - val_recall: 0.7020 - val_auc: 0.7817 - val_fp: 45.0000 - val_fn: 45.0000 - val_tp: 106.0000 - val_tn: 106.0000
# Epoch 6/200
# 27/27 [==============================] - 2s 59ms/step - loss: 0.6210 - acc: 0.7044 - precision: 0.6565 - recall: 0.6620 - auc: 0.7196 - fp: 294.0000 - fn: 287.0000 - tp: 562.0000 - tn: 555.0000 - val_loss: 0.5750 - val_acc: 0.8013 - val_precision: 0.7107 - val_recall: 0.7483 - val_auc: 0.8035 - val_fp: 46.0000 - val_fn: 38.0000 - val_tp: 113.0000 - val_tn: 105.0000
# Epoch 7/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.5976 - acc: 0.7456 - precision: 0.7019 - recall: 0.6796 - auc: 0.7590 - fp: 245.0000 - fn: 272.0000 - tp: 577.0000 - tn: 604.0000 - val_loss: 0.5603 - val_acc: 0.8013 - val_precision: 0.7432 - val_recall: 0.7285 - val_auc: 0.8179 - val_fp: 38.0000 - val_fn: 41.0000 - val_tp: 110.0000 - val_tn: 113.0000
# Epoch 8/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.5940 - acc: 0.7362 - precision: 0.7004 - recall: 0.6938 - auc: 0.7545 - fp: 252.0000 - fn: 260.0000 - tp: 589.0000 - tn: 597.0000 - val_loss: 0.5484 - val_acc: 0.7881 - val_precision: 0.7403 - val_recall: 0.7550 - val_auc: 0.8296 - val_fp: 40.0000 - val_fn: 37.0000 - val_tp: 114.0000 - val_tn: 111.0000
# Epoch 9/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.5736 - acc: 0.7303 - precision: 0.7129 - recall: 0.7138 - auc: 0.7805 - fp: 244.0000 - fn: 243.0000 - tp: 606.0000 - tn: 605.0000 - val_loss: 0.5383 - val_acc: 0.8013 - val_precision: 0.7917 - val_recall: 0.7550 - val_auc: 0.8382 - val_fp: 30.0000 - val_fn: 37.0000 - val_tp: 114.0000 - val_tn: 121.0000
# Epoch 10/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.5700 - acc: 0.7527 - precision: 0.7119 - recall: 0.7161 - auc: 0.7841 - fp: 246.0000 - fn: 241.0000 - tp: 608.0000 - tn: 603.0000 - val_loss: 0.5297 - val_acc: 0.7947 - val_precision: 0.7877 - val_recall: 0.7616 - val_auc: 0.8446 - val_fp: 31.0000 - val_fn: 36.0000 - val_tp: 115.0000 - val_tn: 120.0000
# Epoch 11/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.5589 - acc: 0.7633 - precision: 0.7220 - recall: 0.7220 - auc: 0.7977 - fp: 236.0000 - fn: 236.0000 - tp: 613.0000 - tn: 613.0000 - val_loss: 0.5221 - val_acc: 0.7881 - val_precision: 0.7755 - val_recall: 0.7550 - val_auc: 0.8499 - val_fp: 33.0000 - val_fn: 37.0000 - val_tp: 114.0000 - val_tn: 118.0000
# Epoch 12/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.5474 - acc: 0.7750 - precision: 0.7348 - recall: 0.7244 - auc: 0.8117 - fp: 222.0000 - fn: 234.0000 - tp: 615.0000 - tn: 627.0000 - val_loss: 0.5162 - val_acc: 0.7748 - val_precision: 0.7687 - val_recall: 0.7483 - val_auc: 0.8548 - val_fp: 34.0000 - val_fn: 38.0000 - val_tp: 113.0000 - val_tn: 117.0000
# Epoch 13/200
# 27/27 [==============================] - 2s 59ms/step - loss: 0.5468 - acc: 0.7786 - precision: 0.7412 - recall: 0.7420 - auc: 0.8131 - fp: 220.0000 - fn: 219.0000 - tp: 630.0000 - tn: 629.0000 - val_loss: 0.5093 - val_acc: 0.8146 - val_precision: 0.8112 - val_recall: 0.7682 - val_auc: 0.8566 - val_fp: 27.0000 - val_fn: 35.0000 - val_tp: 116.0000 - val_tn: 124.0000
# Epoch 14/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.5342 - acc: 0.7833 - precision: 0.7453 - recall: 0.7444 - auc: 0.8246 - fp: 216.0000 - fn: 217.0000 - tp: 632.0000 - tn: 633.0000 - val_loss: 0.5034 - val_acc: 0.7748 - val_precision: 0.7667 - val_recall: 0.7616 - val_auc: 0.8601 - val_fp: 35.0000 - val_fn: 36.0000 - val_tp: 115.0000 - val_tn: 116.0000
# Epoch 15/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.5213 - acc: 0.7845 - precision: 0.7739 - recall: 0.7538 - auc: 0.8364 - fp: 187.0000 - fn: 209.0000 - tp: 640.0000 - tn: 662.0000 - val_loss: 0.4975 - val_acc: 0.8146 - val_precision: 0.8000 - val_recall: 0.7682 - val_auc: 0.8626 - val_fp: 29.0000 - val_fn: 35.0000 - val_tp: 116.0000 - val_tn: 122.0000
# Epoch 16/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.5159 - acc: 0.7762 - precision: 0.7650 - recall: 0.7786 - auc: 0.8407 - fp: 203.0000 - fn: 188.0000 - tp: 661.0000 - tn: 646.0000 - val_loss: 0.4928 - val_acc: 0.7947 - val_precision: 0.7908 - val_recall: 0.8013 - val_auc: 0.8642 - val_fp: 32.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 119.0000
# Epoch 17/200
# 27/27 [==============================] - 2s 59ms/step - loss: 0.5015 - acc: 0.7998 - precision: 0.7762 - recall: 0.7762 - auc: 0.8545 - fp: 190.0000 - fn: 190.0000 - tp: 659.0000 - tn: 659.0000 - val_loss: 0.4883 - val_acc: 0.8212 - val_precision: 0.7973 - val_recall: 0.7815 - val_auc: 0.8662 - val_fp: 30.0000 - val_fn: 33.0000 - val_tp: 118.0000 - val_tn: 121.0000
# Epoch 18/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.5000 - acc: 0.8068 - precision: 0.7765 - recall: 0.7691 - auc: 0.8535 - fp: 188.0000 - fn: 196.0000 - tp: 653.0000 - tn: 661.0000 - val_loss: 0.4840 - val_acc: 0.8079 - val_precision: 0.7947 - val_recall: 0.7947 - val_auc: 0.8674 - val_fp: 31.0000 - val_fn: 31.0000 - val_tp: 120.0000 - val_tn: 120.0000
# Epoch 19/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.5030 - acc: 0.8057 - precision: 0.7782 - recall: 0.7727 - auc: 0.8477 - fp: 187.0000 - fn: 193.0000 - tp: 656.0000 - tn: 662.0000 - val_loss: 0.4802 - val_acc: 0.8013 - val_precision: 0.8000 - val_recall: 0.7947 - val_auc: 0.8697 - val_fp: 30.0000 - val_fn: 31.0000 - val_tp: 120.0000 - val_tn: 121.0000
# Epoch 20/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.4956 - acc: 0.8057 - precision: 0.7738 - recall: 0.7856 - auc: 0.8546 - fp: 195.0000 - fn: 182.0000 - tp: 667.0000 - tn: 654.0000 - val_loss: 0.4769 - val_acc: 0.8146 - val_precision: 0.8000 - val_recall: 0.7947 - val_auc: 0.8723 - val_fp: 30.0000 - val_fn: 31.0000 - val_tp: 120.0000 - val_tn: 121.0000
# Epoch 21/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.4818 - acc: 0.8210 - precision: 0.7969 - recall: 0.7903 - auc: 0.8676 - fp: 171.0000 - fn: 178.0000 - tp: 671.0000 - tn: 678.0000 - val_loss: 0.4728 - val_acc: 0.8212 - val_precision: 0.8079 - val_recall: 0.8079 - val_auc: 0.8735 - val_fp: 29.0000 - val_fn: 29.0000 - val_tp: 122.0000 - val_tn: 122.0000
# Epoch 22/200
# 27/27 [==============================] - 2s 59ms/step - loss: 0.4844 - acc: 0.8104 - precision: 0.7969 - recall: 0.7809 - auc: 0.8615 - fp: 169.0000 - fn: 186.0000 - tp: 663.0000 - tn: 680.0000 - val_loss: 0.4695 - val_acc: 0.8278 - val_precision: 0.8092 - val_recall: 0.8146 - val_auc: 0.8751 - val_fp: 29.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 122.0000
# Epoch 23/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.4700 - acc: 0.8127 - precision: 0.8038 - recall: 0.8009 - auc: 0.8772 - fp: 166.0000 - fn: 169.0000 - tp: 680.0000 - tn: 683.0000 - val_loss: 0.4665 - val_acc: 0.8278 - val_precision: 0.8026 - val_recall: 0.8079 - val_auc: 0.8761 - val_fp: 30.0000 - val_fn: 29.0000 - val_tp: 122.0000 - val_tn: 121.0000
# Epoch 24/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.4735 - acc: 0.8139 - precision: 0.7897 - recall: 0.7962 - auc: 0.8685 - fp: 180.0000 - fn: 173.0000 - tp: 676.0000 - tn: 669.0000 - val_loss: 0.4638 - val_acc: 0.8278 - val_precision: 0.8039 - val_recall: 0.8146 - val_auc: 0.8765 - val_fp: 30.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 121.0000
# Epoch 25/200
# 27/27 [==============================] - 1s 55ms/step - loss: 0.4671 - acc: 0.8186 - precision: 0.8085 - recall: 0.8057 - auc: 0.8787 - fp: 162.0000 - fn: 165.0000 - tp: 684.0000 - tn: 687.0000 - val_loss: 0.4610 - val_acc: 0.8278 - val_precision: 0.8176 - val_recall: 0.8013 - val_auc: 0.8772 - val_fp: 27.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 124.0000
# Epoch 26/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.4646 - acc: 0.8245 - precision: 0.8047 - recall: 0.8009 - auc: 0.8781 - fp: 165.0000 - fn: 169.0000 - tp: 680.0000 - tn: 684.0000 - val_loss: 0.4581 - val_acc: 0.8079 - val_precision: 0.8133 - val_recall: 0.8079 - val_auc: 0.8784 - val_fp: 28.0000 - val_fn: 29.0000 - val_tp: 122.0000 - val_tn: 123.0000
# Epoch 27/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.4547 - acc: 0.8186 - precision: 0.8095 - recall: 0.8057 - auc: 0.8855 - fp: 161.0000 - fn: 165.0000 - tp: 684.0000 - tn: 688.0000 - val_loss: 0.4559 - val_acc: 0.8278 - val_precision: 0.8163 - val_recall: 0.7947 - val_auc: 0.8794 - val_fp: 27.0000 - val_fn: 31.0000 - val_tp: 120.0000 - val_tn: 124.0000
# Epoch 28/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.4516 - acc: 0.8292 - precision: 0.8132 - recall: 0.8104 - auc: 0.8883 - fp: 158.0000 - fn: 161.0000 - tp: 688.0000 - tn: 691.0000 - val_loss: 0.4530 - val_acc: 0.8212 - val_precision: 0.8133 - val_recall: 0.8079 - val_auc: 0.8802 - val_fp: 28.0000 - val_fn: 29.0000 - val_tp: 122.0000 - val_tn: 123.0000
# Epoch 29/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.4494 - acc: 0.8280 - precision: 0.8146 - recall: 0.8021 - auc: 0.8873 - fp: 155.0000 - fn: 168.0000 - tp: 681.0000 - tn: 694.0000 - val_loss: 0.4499 - val_acc: 0.8146 - val_precision: 0.8052 - val_recall: 0.8212 - val_auc: 0.8811 - val_fp: 30.0000 - val_fn: 27.0000 - val_tp: 124.0000 - val_tn: 121.0000
# Epoch 30/200
# 27/27 [==============================] - 2s 58ms/step - loss: 0.4415 - acc: 0.8375 - precision: 0.8153 - recall: 0.8163 - auc: 0.8946 - fp: 157.0000 - fn: 156.0000 - tp: 693.0000 - tn: 692.0000 - val_loss: 0.4476 - val_acc: 0.8344 - val_precision: 0.8231 - val_recall: 0.8013 - val_auc: 0.8819 - val_fp: 26.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 125.0000
# Epoch 31/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.4378 - acc: 0.8386 - precision: 0.8097 - recall: 0.8068 - auc: 0.8970 - fp: 161.0000 - fn: 164.0000 - tp: 685.0000 - tn: 688.0000 - val_loss: 0.4449 - val_acc: 0.8278 - val_precision: 0.8133 - val_recall: 0.8079 - val_auc: 0.8827 - val_fp: 28.0000 - val_fn: 29.0000 - val_tp: 122.0000 - val_tn: 123.0000
# Epoch 32/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.4412 - acc: 0.8316 - precision: 0.8123 - recall: 0.8104 - auc: 0.8919 - fp: 159.0000 - fn: 161.0000 - tp: 688.0000 - tn: 690.0000 - val_loss: 0.4430 - val_acc: 0.8344 - val_precision: 0.8219 - val_recall: 0.7947 - val_auc: 0.8836 - val_fp: 26.0000 - val_fn: 31.0000 - val_tp: 120.0000 - val_tn: 125.0000
# Epoch 33/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.4316 - acc: 0.8469 - precision: 0.8191 - recall: 0.8269 - auc: 0.8992 - fp: 155.0000 - fn: 147.0000 - tp: 702.0000 - tn: 694.0000 - val_loss: 0.4412 - val_acc: 0.8278 - val_precision: 0.8092 - val_recall: 0.8146 - val_auc: 0.8842 - val_fp: 29.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 122.0000
# Epoch 34/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.4272 - acc: 0.8575 - precision: 0.8406 - recall: 0.8198 - auc: 0.9029 - fp: 132.0000 - fn: 153.0000 - tp: 696.0000 - tn: 717.0000 - val_loss: 0.4389 - val_acc: 0.8278 - val_precision: 0.8121 - val_recall: 0.8013 - val_auc: 0.8849 - val_fp: 28.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 123.0000
# Epoch 35/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.4224 - acc: 0.8563 - precision: 0.8306 - recall: 0.8375 - auc: 0.9061 - fp: 145.0000 - fn: 138.0000 - tp: 711.0000 - tn: 704.0000 - val_loss: 0.4367 - val_acc: 0.8212 - val_precision: 0.8146 - val_recall: 0.8146 - val_auc: 0.8858 - val_fp: 28.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 123.0000
# Epoch 36/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.4245 - acc: 0.8351 - precision: 0.8098 - recall: 0.8174 - auc: 0.9025 - fp: 163.0000 - fn: 155.0000 - tp: 694.0000 - tn: 686.0000 - val_loss: 0.4347 - val_acc: 0.8212 - val_precision: 0.8067 - val_recall: 0.8013 - val_auc: 0.8873 - val_fp: 29.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 122.0000
# Epoch 37/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.4148 - acc: 0.8551 - precision: 0.8383 - recall: 0.8304 - auc: 0.9118 - fp: 136.0000 - fn: 144.0000 - tp: 705.0000 - tn: 713.0000 - val_loss: 0.4327 - val_acc: 0.8212 - val_precision: 0.8121 - val_recall: 0.8013 - val_auc: 0.8877 - val_fp: 28.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 123.0000
# Epoch 38/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.4160 - acc: 0.8433 - precision: 0.8308 - recall: 0.8327 - auc: 0.9098 - fp: 144.0000 - fn: 142.0000 - tp: 707.0000 - tn: 705.0000 - val_loss: 0.4311 - val_acc: 0.8212 - val_precision: 0.8052 - val_recall: 0.8212 - val_auc: 0.8890 - val_fp: 30.0000 - val_fn: 27.0000 - val_tp: 124.0000 - val_tn: 121.0000
# Epoch 39/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.4145 - acc: 0.8398 - precision: 0.8451 - recall: 0.8163 - auc: 0.9082 - fp: 127.0000 - fn: 156.0000 - tp: 693.0000 - tn: 722.0000 - val_loss: 0.4293 - val_acc: 0.8212 - val_precision: 0.8163 - val_recall: 0.7947 - val_auc: 0.8889 - val_fp: 27.0000 - val_fn: 31.0000 - val_tp: 120.0000 - val_tn: 124.0000
# Epoch 40/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.4046 - acc: 0.8563 - precision: 0.8425 - recall: 0.8445 - auc: 0.9138 - fp: 134.0000 - fn: 132.0000 - tp: 717.0000 - tn: 715.0000 - val_loss: 0.4278 - val_acc: 0.8278 - val_precision: 0.8288 - val_recall: 0.8013 - val_auc: 0.8899 - val_fp: 25.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 126.0000
# Epoch 41/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.4014 - acc: 0.8551 - precision: 0.8392 - recall: 0.8363 - auc: 0.9178 - fp: 136.0000 - fn: 139.0000 - tp: 710.0000 - tn: 713.0000 - val_loss: 0.4256 - val_acc: 0.8212 - val_precision: 0.8079 - val_recall: 0.8079 - val_auc: 0.8908 - val_fp: 29.0000 - val_fn: 29.0000 - val_tp: 122.0000 - val_tn: 122.0000
# Epoch 42/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.4102 - acc: 0.8492 - precision: 0.8345 - recall: 0.8257 - auc: 0.9096 - fp: 139.0000 - fn: 148.0000 - tp: 701.0000 - tn: 710.0000 - val_loss: 0.4237 - val_acc: 0.8212 - val_precision: 0.8133 - val_recall: 0.8079 - val_auc: 0.8914 - val_fp: 28.0000 - val_fn: 29.0000 - val_tp: 122.0000 - val_tn: 123.0000
# Epoch 43/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.4009 - acc: 0.8469 - precision: 0.8382 - recall: 0.8422 - auc: 0.9156 - fp: 138.0000 - fn: 134.0000 - tp: 715.0000 - tn: 711.0000 - val_loss: 0.4219 - val_acc: 0.8212 - val_precision: 0.8231 - val_recall: 0.8013 - val_auc: 0.8922 - val_fp: 26.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 125.0000
# Epoch 44/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3951 - acc: 0.8528 - precision: 0.8428 - recall: 0.8528 - auc: 0.9219 - fp: 135.0000 - fn: 125.0000 - tp: 724.0000 - tn: 714.0000 - val_loss: 0.4206 - val_acc: 0.8212 - val_precision: 0.8067 - val_recall: 0.8013 - val_auc: 0.8930 - val_fp: 29.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 122.0000
# Epoch 45/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3861 - acc: 0.8634 - precision: 0.8604 - recall: 0.8492 - auc: 0.9250 - fp: 117.0000 - fn: 128.0000 - tp: 721.0000 - tn: 732.0000 - val_loss: 0.4188 - val_acc: 0.8212 - val_precision: 0.8163 - val_recall: 0.7947 - val_auc: 0.8937 - val_fp: 27.0000 - val_fn: 31.0000 - val_tp: 120.0000 - val_tn: 124.0000
# Epoch 46/200
# 27/27 [==============================] - 1s 55ms/step - loss: 0.3918 - acc: 0.8410 - precision: 0.8441 - recall: 0.8292 - auc: 0.9210 - fp: 130.0000 - fn: 145.0000 - tp: 704.0000 - tn: 719.0000 - val_loss: 0.4180 - val_acc: 0.8212 - val_precision: 0.8231 - val_recall: 0.8013 - val_auc: 0.8940 - val_fp: 26.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 125.0000
# Epoch 47/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3813 - acc: 0.8681 - precision: 0.8662 - recall: 0.8693 - auc: 0.9298 - fp: 114.0000 - fn: 111.0000 - tp: 738.0000 - tn: 735.0000 - val_loss: 0.4163 - val_acc: 0.8212 - val_precision: 0.8067 - val_recall: 0.8013 - val_auc: 0.8953 - val_fp: 29.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 122.0000
# Epoch 48/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3775 - acc: 0.8657 - precision: 0.8607 - recall: 0.8657 - auc: 0.9318 - fp: 119.0000 - fn: 114.0000 - tp: 735.0000 - tn: 730.0000 - val_loss: 0.4147 - val_acc: 0.8212 - val_precision: 0.8231 - val_recall: 0.8013 - val_auc: 0.8954 - val_fp: 26.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 125.0000
# Epoch 49/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3827 - acc: 0.8610 - precision: 0.8538 - recall: 0.8528 - auc: 0.9244 - fp: 124.0000 - fn: 125.0000 - tp: 724.0000 - tn: 725.0000 - val_loss: 0.4131 - val_acc: 0.8212 - val_precision: 0.8219 - val_recall: 0.7947 - val_auc: 0.8963 - val_fp: 26.0000 - val_fn: 31.0000 - val_tp: 120.0000 - val_tn: 125.0000
# Epoch 50/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3770 - acc: 0.8587 - precision: 0.8474 - recall: 0.8504 - auc: 0.9300 - fp: 130.0000 - fn: 127.0000 - tp: 722.0000 - tn: 719.0000 - val_loss: 0.4117 - val_acc: 0.8212 - val_precision: 0.8207 - val_recall: 0.7881 - val_auc: 0.8970 - val_fp: 26.0000 - val_fn: 32.0000 - val_tp: 119.0000 - val_tn: 125.0000
# Epoch 51/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3796 - acc: 0.8645 - precision: 0.8470 - recall: 0.8539 - auc: 0.9270 - fp: 131.0000 - fn: 124.0000 - tp: 725.0000 - tn: 718.0000 - val_loss: 0.4101 - val_acc: 0.8344 - val_precision: 0.8219 - val_recall: 0.7947 - val_auc: 0.8980 - val_fp: 26.0000 - val_fn: 31.0000 - val_tp: 120.0000 - val_tn: 125.0000
# Epoch 52/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3723 - acc: 0.8669 - precision: 0.8621 - recall: 0.8469 - auc: 0.9320 - fp: 115.0000 - fn: 130.0000 - tp: 719.0000 - tn: 734.0000 - val_loss: 0.4092 - val_acc: 0.8278 - val_precision: 0.8288 - val_recall: 0.8013 - val_auc: 0.8984 - val_fp: 25.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 126.0000
# Epoch 53/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.3742 - acc: 0.8740 - precision: 0.8598 - recall: 0.8598 - auc: 0.9326 - fp: 119.0000 - fn: 119.0000 - tp: 730.0000 - tn: 730.0000 - val_loss: 0.4077 - val_acc: 0.8278 - val_precision: 0.8231 - val_recall: 0.8013 - val_auc: 0.8991 - val_fp: 26.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 125.0000
# Epoch 54/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3748 - acc: 0.8551 - precision: 0.8397 - recall: 0.8516 - auc: 0.9287 - fp: 138.0000 - fn: 126.0000 - tp: 723.0000 - tn: 711.0000 - val_loss: 0.4059 - val_acc: 0.8212 - val_precision: 0.8188 - val_recall: 0.8079 - val_auc: 0.8994 - val_fp: 27.0000 - val_fn: 29.0000 - val_tp: 122.0000 - val_tn: 124.0000
# Epoch 55/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3768 - acc: 0.8551 - precision: 0.8454 - recall: 0.8504 - auc: 0.9259 - fp: 132.0000 - fn: 127.0000 - tp: 722.0000 - tn: 717.0000 - val_loss: 0.4059 - val_acc: 0.8212 - val_precision: 0.8403 - val_recall: 0.8013 - val_auc: 0.8999 - val_fp: 23.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 128.0000
# Epoch 56/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3709 - acc: 0.8622 - precision: 0.8498 - recall: 0.8528 - auc: 0.9297 - fp: 128.0000 - fn: 125.0000 - tp: 724.0000 - tn: 721.0000 - val_loss: 0.4032 - val_acc: 0.8344 - val_precision: 0.8200 - val_recall: 0.8146 - val_auc: 0.9004 - val_fp: 27.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 124.0000
# Epoch 57/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3658 - acc: 0.8598 - precision: 0.8461 - recall: 0.8481 - auc: 0.9332 - fp: 131.0000 - fn: 129.0000 - tp: 720.0000 - tn: 718.0000 - val_loss: 0.4019 - val_acc: 0.8344 - val_precision: 0.8264 - val_recall: 0.7881 - val_auc: 0.9007 - val_fp: 25.0000 - val_fn: 32.0000 - val_tp: 119.0000 - val_tn: 126.0000
# Epoch 58/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3615 - acc: 0.8740 - precision: 0.8712 - recall: 0.8681 - auc: 0.9374 - fp: 109.0000 - fn: 112.0000 - tp: 737.0000 - tn: 740.0000 - val_loss: 0.4004 - val_acc: 0.8344 - val_precision: 0.8133 - val_recall: 0.8079 - val_auc: 0.9022 - val_fp: 28.0000 - val_fn: 29.0000 - val_tp: 122.0000 - val_tn: 123.0000
# Epoch 59/200
# 27/27 [==============================] - 2s 58ms/step - loss: 0.3576 - acc: 0.8681 - precision: 0.8605 - recall: 0.8645 - auc: 0.9378 - fp: 119.0000 - fn: 115.0000 - tp: 734.0000 - tn: 730.0000 - val_loss: 0.3991 - val_acc: 0.8411 - val_precision: 0.8188 - val_recall: 0.8079 - val_auc: 0.9021 - val_fp: 27.0000 - val_fn: 29.0000 - val_tp: 122.0000 - val_tn: 124.0000
# Epoch 60/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3677 - acc: 0.8634 - precision: 0.8479 - recall: 0.8598 - auc: 0.9296 - fp: 131.0000 - fn: 119.0000 - tp: 730.0000 - tn: 718.0000 - val_loss: 0.3983 - val_acc: 0.8278 - val_precision: 0.8151 - val_recall: 0.7881 - val_auc: 0.9026 - val_fp: 27.0000 - val_fn: 32.0000 - val_tp: 119.0000 - val_tn: 124.0000
# Epoch 61/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3592 - acc: 0.8634 - precision: 0.8582 - recall: 0.8551 - auc: 0.9342 - fp: 120.0000 - fn: 123.0000 - tp: 726.0000 - tn: 729.0000 - val_loss: 0.3972 - val_acc: 0.8344 - val_precision: 0.8163 - val_recall: 0.7947 - val_auc: 0.9026 - val_fp: 27.0000 - val_fn: 31.0000 - val_tp: 120.0000 - val_tn: 124.0000
# Epoch 62/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3553 - acc: 0.8669 - precision: 0.8550 - recall: 0.8539 - auc: 0.9367 - fp: 123.0000 - fn: 124.0000 - tp: 725.0000 - tn: 726.0000 - val_loss: 0.3962 - val_acc: 0.8278 - val_precision: 0.8345 - val_recall: 0.8013 - val_auc: 0.9033 - val_fp: 24.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 127.0000
# Epoch 63/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3502 - acc: 0.8693 - precision: 0.8616 - recall: 0.8504 - auc: 0.9389 - fp: 116.0000 - fn: 127.0000 - tp: 722.0000 - tn: 733.0000 - val_loss: 0.3950 - val_acc: 0.8344 - val_precision: 0.8146 - val_recall: 0.8146 - val_auc: 0.9035 - val_fp: 28.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 123.0000
# Epoch 64/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3507 - acc: 0.8681 - precision: 0.8651 - recall: 0.8610 - auc: 0.9395 - fp: 114.0000 - fn: 118.0000 - tp: 731.0000 - tn: 735.0000 - val_loss: 0.3949 - val_acc: 0.8212 - val_precision: 0.8414 - val_recall: 0.8079 - val_auc: 0.9039 - val_fp: 23.0000 - val_fn: 29.0000 - val_tp: 122.0000 - val_tn: 128.0000
# Epoch 65/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3484 - acc: 0.8681 - precision: 0.8630 - recall: 0.8681 - auc: 0.9408 - fp: 117.0000 - fn: 112.0000 - tp: 737.0000 - tn: 732.0000 - val_loss: 0.3937 - val_acc: 0.8212 - val_precision: 0.8414 - val_recall: 0.8079 - val_auc: 0.9045 - val_fp: 23.0000 - val_fn: 29.0000 - val_tp: 122.0000 - val_tn: 128.0000
# Epoch 66/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3398 - acc: 0.8657 - precision: 0.8638 - recall: 0.8669 - auc: 0.9465 - fp: 116.0000 - fn: 113.0000 - tp: 736.0000 - tn: 733.0000 - val_loss: 0.3918 - val_acc: 0.8278 - val_precision: 0.8288 - val_recall: 0.8013 - val_auc: 0.9048 - val_fp: 25.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 126.0000
# Epoch 67/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3538 - acc: 0.8693 - precision: 0.8560 - recall: 0.8539 - auc: 0.9367 - fp: 122.0000 - fn: 124.0000 - tp: 725.0000 - tn: 727.0000 - val_loss: 0.3910 - val_acc: 0.8278 - val_precision: 0.8345 - val_recall: 0.8013 - val_auc: 0.9050 - val_fp: 24.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 127.0000
# Epoch 68/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3449 - acc: 0.8716 - precision: 0.8665 - recall: 0.8716 - auc: 0.9435 - fp: 114.0000 - fn: 109.0000 - tp: 740.0000 - tn: 735.0000 - val_loss: 0.3899 - val_acc: 0.8212 - val_precision: 0.8231 - val_recall: 0.8013 - val_auc: 0.9058 - val_fp: 26.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 125.0000
# Epoch 69/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3409 - acc: 0.8822 - precision: 0.8781 - recall: 0.8657 - auc: 0.9450 - fp: 102.0000 - fn: 114.0000 - tp: 735.0000 - tn: 747.0000 - val_loss: 0.3885 - val_acc: 0.8278 - val_precision: 0.8345 - val_recall: 0.8013 - val_auc: 0.9070 - val_fp: 24.0000 - val_fn: 30.0000 - val_tp: 121.0000 - val_tn: 127.0000
# Epoch 70/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3440 - acc: 0.8799 - precision: 0.8793 - recall: 0.8751 - auc: 0.9406 - fp: 102.0000 - fn: 106.0000 - tp: 743.0000 - tn: 747.0000 - val_loss: 0.3881 - val_acc: 0.8278 - val_precision: 0.8414 - val_recall: 0.8079 - val_auc: 0.9076 - val_fp: 23.0000 - val_fn: 29.0000 - val_tp: 122.0000 - val_tn: 128.0000
# Epoch 71/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3444 - acc: 0.8657 - precision: 0.8636 - recall: 0.8575 - auc: 0.9398 - fp: 115.0000 - fn: 121.0000 - tp: 728.0000 - tn: 734.0000 - val_loss: 0.3870 - val_acc: 0.8278 - val_precision: 0.8414 - val_recall: 0.8079 - val_auc: 0.9082 - val_fp: 23.0000 - val_fn: 29.0000 - val_tp: 122.0000 - val_tn: 128.0000
# Epoch 72/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3365 - acc: 0.8846 - precision: 0.8793 - recall: 0.8751 - auc: 0.9461 - fp: 102.0000 - fn: 106.0000 - tp: 743.0000 - tn: 747.0000 - val_loss: 0.3860 - val_acc: 0.8344 - val_precision: 0.8311 - val_recall: 0.8146 - val_auc: 0.9082 - val_fp: 25.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 126.0000
# Epoch 73/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3393 - acc: 0.8669 - precision: 0.8677 - recall: 0.8575 - auc: 0.9428 - fp: 111.0000 - fn: 121.0000 - tp: 728.0000 - tn: 738.0000 - val_loss: 0.3847 - val_acc: 0.8278 - val_precision: 0.8356 - val_recall: 0.8079 - val_auc: 0.9086 - val_fp: 24.0000 - val_fn: 29.0000 - val_tp: 122.0000 - val_tn: 127.0000
# Epoch 74/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3315 - acc: 0.8810 - precision: 0.8670 - recall: 0.8751 - auc: 0.9483 - fp: 114.0000 - fn: 106.0000 - tp: 743.0000 - tn: 735.0000 - val_loss: 0.3839 - val_acc: 0.8278 - val_precision: 0.8299 - val_recall: 0.8079 - val_auc: 0.9094 - val_fp: 25.0000 - val_fn: 29.0000 - val_tp: 122.0000 - val_tn: 126.0000
# Epoch 75/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3289 - acc: 0.8775 - precision: 0.8768 - recall: 0.8634 - auc: 0.9502 - fp: 103.0000 - fn: 116.0000 - tp: 733.0000 - tn: 746.0000 - val_loss: 0.3829 - val_acc: 0.8278 - val_precision: 0.8367 - val_recall: 0.8146 - val_auc: 0.9098 - val_fp: 24.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 127.0000
# Epoch 76/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3291 - acc: 0.8716 - precision: 0.8787 - recall: 0.8704 - auc: 0.9471 - fp: 102.0000 - fn: 110.0000 - tp: 739.0000 - tn: 747.0000 - val_loss: 0.3813 - val_acc: 0.8278 - val_precision: 0.8367 - val_recall: 0.8146 - val_auc: 0.9097 - val_fp: 24.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 127.0000
# Epoch 77/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3302 - acc: 0.8716 - precision: 0.8660 - recall: 0.8681 - auc: 0.9473 - fp: 114.0000 - fn: 112.0000 - tp: 737.0000 - tn: 735.0000 - val_loss: 0.3807 - val_acc: 0.8278 - val_precision: 0.8378 - val_recall: 0.8212 - val_auc: 0.9107 - val_fp: 24.0000 - val_fn: 27.0000 - val_tp: 124.0000 - val_tn: 127.0000
# Epoch 78/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3284 - acc: 0.8775 - precision: 0.8747 - recall: 0.8799 - auc: 0.9491 - fp: 107.0000 - fn: 102.0000 - tp: 747.0000 - tn: 742.0000 - val_loss: 0.3795 - val_acc: 0.8278 - val_precision: 0.8367 - val_recall: 0.8146 - val_auc: 0.9110 - val_fp: 24.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 127.0000
# Epoch 79/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3223 - acc: 0.8857 - precision: 0.8842 - recall: 0.8810 - auc: 0.9527 - fp: 98.0000 - fn: 101.0000 - tp: 748.0000 - tn: 751.0000 - val_loss: 0.3789 - val_acc: 0.8278 - val_precision: 0.8356 - val_recall: 0.8079 - val_auc: 0.9113 - val_fp: 24.0000 - val_fn: 29.0000 - val_tp: 122.0000 - val_tn: 127.0000
# Epoch 80/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3292 - acc: 0.8810 - precision: 0.8825 - recall: 0.8669 - auc: 0.9490 - fp: 98.0000 - fn: 113.0000 - tp: 736.0000 - tn: 751.0000 - val_loss: 0.3781 - val_acc: 0.8278 - val_precision: 0.8378 - val_recall: 0.8212 - val_auc: 0.9116 - val_fp: 24.0000 - val_fn: 27.0000 - val_tp: 124.0000 - val_tn: 127.0000
# Epoch 81/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.3089 - acc: 0.8975 - precision: 0.8935 - recall: 0.8893 - auc: 0.9592 - fp: 90.0000 - fn: 94.0000 - tp: 755.0000 - tn: 759.0000 - val_loss: 0.3770 - val_acc: 0.8212 - val_precision: 0.8367 - val_recall: 0.8146 - val_auc: 0.9119 - val_fp: 24.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 127.0000
# Epoch 82/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3159 - acc: 0.8857 - precision: 0.8884 - recall: 0.8810 - auc: 0.9560 - fp: 94.0000 - fn: 101.0000 - tp: 748.0000 - tn: 755.0000 - val_loss: 0.3774 - val_acc: 0.8344 - val_precision: 0.8188 - val_recall: 0.8079 - val_auc: 0.9121 - val_fp: 27.0000 - val_fn: 29.0000 - val_tp: 122.0000 - val_tn: 124.0000
# Epoch 83/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3169 - acc: 0.8963 - precision: 0.8852 - recall: 0.8905 - auc: 0.9537 - fp: 98.0000 - fn: 93.0000 - tp: 756.0000 - tn: 751.0000 - val_loss: 0.3749 - val_acc: 0.8212 - val_precision: 0.8367 - val_recall: 0.8146 - val_auc: 0.9126 - val_fp: 24.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 127.0000
# Epoch 84/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.3236 - acc: 0.8810 - precision: 0.8756 - recall: 0.8787 - auc: 0.9487 - fp: 106.0000 - fn: 103.0000 - tp: 746.0000 - tn: 743.0000 - val_loss: 0.3743 - val_acc: 0.8344 - val_precision: 0.8322 - val_recall: 0.8212 - val_auc: 0.9128 - val_fp: 25.0000 - val_fn: 27.0000 - val_tp: 124.0000 - val_tn: 126.0000
# Epoch 85/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3184 - acc: 0.8905 - precision: 0.8801 - recall: 0.8822 - auc: 0.9512 - fp: 102.0000 - fn: 100.0000 - tp: 749.0000 - tn: 747.0000 - val_loss: 0.3738 - val_acc: 0.8344 - val_precision: 0.8367 - val_recall: 0.8146 - val_auc: 0.9131 - val_fp: 24.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 127.0000
# Epoch 86/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3119 - acc: 0.8857 - precision: 0.8851 - recall: 0.8799 - auc: 0.9558 - fp: 97.0000 - fn: 102.0000 - tp: 747.0000 - tn: 752.0000 - val_loss: 0.3730 - val_acc: 0.8344 - val_precision: 0.8378 - val_recall: 0.8212 - val_auc: 0.9133 - val_fp: 24.0000 - val_fn: 27.0000 - val_tp: 124.0000 - val_tn: 127.0000
# Epoch 87/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3093 - acc: 0.8928 - precision: 0.8892 - recall: 0.8881 - auc: 0.9567 - fp: 94.0000 - fn: 95.0000 - tp: 754.0000 - tn: 755.0000 - val_loss: 0.3720 - val_acc: 0.8344 - val_precision: 0.8483 - val_recall: 0.8146 - val_auc: 0.9136 - val_fp: 22.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 129.0000
# Epoch 88/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.3117 - acc: 0.8905 - precision: 0.8914 - recall: 0.8799 - auc: 0.9545 - fp: 91.0000 - fn: 102.0000 - tp: 747.0000 - tn: 758.0000 - val_loss: 0.3713 - val_acc: 0.8344 - val_precision: 0.8425 - val_recall: 0.8146 - val_auc: 0.9139 - val_fp: 23.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 128.0000
# Epoch 89/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3133 - acc: 0.8857 - precision: 0.8787 - recall: 0.8787 - auc: 0.9526 - fp: 103.0000 - fn: 103.0000 - tp: 746.0000 - tn: 746.0000 - val_loss: 0.3703 - val_acc: 0.8212 - val_precision: 0.8378 - val_recall: 0.8212 - val_auc: 0.9148 - val_fp: 24.0000 - val_fn: 27.0000 - val_tp: 124.0000 - val_tn: 127.0000
# Epoch 90/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3035 - acc: 0.8905 - precision: 0.8836 - recall: 0.8940 - auc: 0.9586 - fp: 100.0000 - fn: 90.0000 - tp: 759.0000 - tn: 749.0000 - val_loss: 0.3697 - val_acc: 0.8212 - val_precision: 0.8367 - val_recall: 0.8146 - val_auc: 0.9151 - val_fp: 24.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 127.0000
# Epoch 91/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3074 - acc: 0.8857 - precision: 0.8837 - recall: 0.8952 - auc: 0.9561 - fp: 100.0000 - fn: 89.0000 - tp: 760.0000 - tn: 749.0000 - val_loss: 0.3689 - val_acc: 0.8278 - val_precision: 0.8425 - val_recall: 0.8146 - val_auc: 0.9154 - val_fp: 23.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 128.0000
# Epoch 92/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3121 - acc: 0.8810 - precision: 0.8747 - recall: 0.8799 - auc: 0.9523 - fp: 107.0000 - fn: 102.0000 - tp: 747.0000 - tn: 742.0000 - val_loss: 0.3682 - val_acc: 0.8278 - val_precision: 0.8435 - val_recall: 0.8212 - val_auc: 0.9158 - val_fp: 23.0000 - val_fn: 27.0000 - val_tp: 124.0000 - val_tn: 128.0000
# Epoch 93/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3100 - acc: 0.8881 - precision: 0.8897 - recall: 0.8834 - auc: 0.9549 - fp: 93.0000 - fn: 99.0000 - tp: 750.0000 - tn: 756.0000 - val_loss: 0.3672 - val_acc: 0.8278 - val_precision: 0.8367 - val_recall: 0.8146 - val_auc: 0.9167 - val_fp: 24.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 127.0000
# Epoch 94/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.2980 - acc: 0.8975 - precision: 0.8842 - recall: 0.8905 - auc: 0.9593 - fp: 99.0000 - fn: 93.0000 - tp: 756.0000 - tn: 750.0000 - val_loss: 0.3664 - val_acc: 0.8278 - val_precision: 0.8322 - val_recall: 0.8212 - val_auc: 0.9170 - val_fp: 25.0000 - val_fn: 27.0000 - val_tp: 124.0000 - val_tn: 126.0000
# Epoch 95/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3029 - acc: 0.8893 - precision: 0.8858 - recall: 0.8952 - auc: 0.9580 - fp: 98.0000 - fn: 89.0000 - tp: 760.0000 - tn: 751.0000 - val_loss: 0.3657 - val_acc: 0.8411 - val_precision: 0.8425 - val_recall: 0.8146 - val_auc: 0.9178 - val_fp: 23.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 128.0000
# Epoch 96/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.2967 - acc: 0.9034 - precision: 0.8986 - recall: 0.8869 - auc: 0.9608 - fp: 85.0000 - fn: 96.0000 - tp: 753.0000 - tn: 764.0000 - val_loss: 0.3650 - val_acc: 0.8344 - val_precision: 0.8311 - val_recall: 0.8146 - val_auc: 0.9185 - val_fp: 25.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 126.0000
# Epoch 97/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3006 - acc: 0.9022 - precision: 0.8912 - recall: 0.8975 - auc: 0.9589 - fp: 93.0000 - fn: 87.0000 - tp: 762.0000 - tn: 756.0000 - val_loss: 0.3640 - val_acc: 0.8344 - val_precision: 0.8322 - val_recall: 0.8212 - val_auc: 0.9182 - val_fp: 25.0000 - val_fn: 27.0000 - val_tp: 124.0000 - val_tn: 126.0000
# Epoch 98/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.2989 - acc: 0.8928 - precision: 0.8902 - recall: 0.8881 - auc: 0.9602 - fp: 93.0000 - fn: 95.0000 - tp: 754.0000 - tn: 756.0000 - val_loss: 0.3633 - val_acc: 0.8344 - val_precision: 0.8311 - val_recall: 0.8146 - val_auc: 0.9189 - val_fp: 25.0000 - val_fn: 28.0000 - val_tp: 123.0000 - val_tn: 126.0000
# Epoch 99/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3032 - acc: 0.8905 - precision: 0.8923 - recall: 0.8881 - auc: 0.9590 - fp: 91.0000 - fn: 95.0000 - tp: 754.0000 - tn: 758.0000Restoring model weights from the end of the best epoch: 59.
# 27/27 [==============================] - 2s 60ms/step - loss: 0.3032 - acc: 0.8905 - precision: 0.8923 - recall: 0.8881 - auc: 0.9590 - fp: 91.0000 - fn: 95.0000 - tp: 754.0000 - tn: 758.0000 - val_loss: 0.3628 - val_acc: 0.8344 - val_precision: 0.8378 - val_recall: 0.8212 - val_auc: 0.9190 - val_fp: 24.0000 - val_fn: 27.0000 - val_tp: 124.0000 - val_tn: 127.0000
# Epoch 99: early stopping

# %% [markdown]
# ### Plotting Accuracy vs epochs and Loss vs epochs graphs

# %%
import matplotlib.pyplot as plt
from PIL import Image

colors = ['blue','orange']
plt.figure(figsize=(15, 12))
metrics = ['acc', 'loss']
    
for i, metric in enumerate(metrics):
    plt.subplot(220 + 1 + i)
    plt.plot(history.epoch, history.history[metric], color=colors[0], label='Train')
    plt.plot(history.epoch, history.history['val_' + metric],
                color=colors[1], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(metric)
    plt.legend()
    #plt.show() 
    plt.savefig('temp_plot.jpeg')  
    temp_plot = Image.open('temp_plot.jpeg')
    temp_plot.save('acc_loss.jpeg')
    temp_plot.close()  
    os.remove('temp_plot.jpeg')

# %% [markdown]
# ### Evaluating the Model using Test dataset
# In this project we have around 900 images which is low so we splitted dataset into train and test dataset and used test dataset for validation as well as testing.

# %%
model.evaluate(X_test,y_test)
# Out:
# 5/5 [==============================] - 0s 46ms/step - loss: 0.3991 - acc: 0.8411 - precision: 0.8188 - recall: 0.8079 - auc: 0.9021 - fp: 27.0000 - fn: 29.0000 - tp: 122.0000 - tn: 124.0000
# [0.39911985397338867,
#  0.8410596251487732,
#  0.818791925907135,
#  0.807947039604187,
#  0.9020722508430481,
#  27.0,
#  29.0,
#  122.0,
#  124.0]

# %% [markdown]
# ### Creating Classification Report and Confusion Matrix based on the prediction by the Model

# %%
y_test_indices = np.argmax(y_test, axis=1)

# Get the predicted class indices using model.predict and np.argmax
y_pred_indices = np.argmax(model.predict(X_test), axis=1)

class_names = ['exo_planet','non_exo_planet']

# Generate and print the classification report
print(classification_report(y_test_indices, y_pred_indices, target_names=class_names))
# Out:
# 5/5 [==============================] - 2s 41ms/step
#                 precision    recall  f1-score   support
#
#     exo_planet       0.82      0.84      0.83        70
# non_exo_planet       0.86      0.84      0.85        81
#
#       accuracy                           0.84       151
#      macro avg       0.84      0.84      0.84       151
#   weighted avg       0.84      0.84      0.84       151

# %%
# Generate the confusion matrix
cm = confusion_matrix(y_test_indices, y_pred_indices)

# Set the font scale
sns.set(font_scale=1.5)

# Plot the heatmap
plt.figure(figsize=(20,12))
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)
plt.xticks(np.arange(2)+.5, class_names, rotation=25)
plt.yticks(np.arange(2)+.5, class_names, rotation=0)
plt.xlabel("Predicted")
plt.ylabel("Actual")
#plt.title("Confusion Matrix")

# Show the plot
#plt.show()
plt.savefig('temp_plot.jpeg')  
temp_plot = Image.open('temp_plot.jpeg')
temp_plot.save('confusion_matrix.jpeg')
temp_plot.close()  
os.remove('temp_plot.jpeg')

# %% [markdown]
# # Fine-Tuning the Pre-trained Deep learning Model

# %% [markdown]
# ### Unfreezing the Bottom-layers of the model and make them untrainable
#
# One way to increase performance even further is to train (or "fine-tune") the weights of the top layers of the pre-trained model alongside the training of the classifier  added. The training process will force the weights to be tuned from generic feature maps to features associated specifically with the dataset.

# %%
base_model.trainable = True

# %%
# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(base_model.layers))

# %% [markdown]
# ### Fine-tuning the Deep Learning Model

# %%
# Fine-tune from this layer onwards
fine_tune_at = 265

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

# %% [markdown]
# ### Again Compiling the Deep Learning Model

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
    loss='categorical_crossentropy',
    metrics=['acc','Precision','Recall',
            tf.keras.metrics.AUC(multi_label=True),
             tf.keras.metrics.FalsePositives(name='fp'),
             tf.keras.metrics.FalseNegatives(name='fn'), 
             tf.keras.metrics.TruePositives(name='tp'), 
             tf.keras.metrics.TrueNegatives(name='tn')
            ]
)

# %%
#len(model.trainable_variables)

# %% [markdown]
# ### Again training the Model after Fine-Tuning

# %%
fine_tune_epochs = 200
total_epochs =  200 + fine_tune_epochs

history = model.fit(X_train, y_train,batch_size =32, epochs=total_epochs,
                    initial_epoch=history.epoch[-1], callbacks=[early_stop], validation_data=(X_test,y_test))

# %% [markdown]
# ### Evaluation of the Model after Fine-Tuning

# %%
model.evaluate(X_test,y_test)

# %% [markdown]
# ### Plotting Accuracy vs epochs and Loss vs epochs graph

# %%
colors = ['blue','orange']
plt.figure(figsize=(15, 12))
metrics = ['acc', 'loss']
    
for i, metric in enumerate(metrics):
    plt.subplot(220 + 1 + i)
    plt.plot(history.epoch, history.history[metric], color=colors[0], label='Train')
    plt.plot(history.epoch, history.history['val_' + metric],
                color=colors[1], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(metric)
    plt.legend()
    plt.savefig('temp_plot.jpeg')  
    temp_plot = Image.open('temp_plot.jpeg')
    temp_plot.save('acc_loss_1.jpeg')
    temp_plot.close()  
    os.remove('temp_plot.jpeg')

# %% [markdown]
# ### Creating Classification Report and Confusion Matrix based on the prediction by the Model

# %%
y_test_indices = np.argmax(y_test, axis=1)

# Get the predicted class indices using model.predict and np.argmax
y_pred_indices = np.argmax(model.predict(X_test), axis = 1)

class_names = ['angry','happy','sad']

# Generate and print the classification report
print(classification_report(y_test_indices, y_pred_indices, target_names=class_names))

# %%
# Generate the confusion matrix
cm = confusion_matrix(y_test_indices, y_pred_indices)

# Set the font scale
sns.set(font_scale=1.5)

# Plot the heatmap
plt.figure(figsize=(20,12))
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)
plt.xticks(np.arange(3)+.5, class_names, rotation=25)
plt.yticks(np.arange(3)+.5, class_names, rotation=0)
plt.xlabel("Predicted")
plt.ylabel("Actual")
#plt.title("Confusion Matrix")

# Show the plot
#plt.show()
plt.savefig('temp_plot.jpeg')  
temp_plot = Image.open('temp_plot.jpeg')
temp_plot.save('confusion_matrix_1.jpeg')
temp_plot.close()  
os.remove('temp_plot.jpeg')

# %% [markdown]
# ### Plotting Receiver Operating Characteristics(ROC) Curve

# %%
y_pred_roc = model.predict(X_test)
# Out:
# 5/5 [==============================] - 0s 42ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp

# Convert class labels to one-hot encoded format
y_test_bin = label_binarize(y_test_indices, classes=[0, 1, 2])

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(y_test_bin.shape[1]):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_pred_roc[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve for each class
plt.figure(figsize=(12, 8))
for i in range(y_test_bin.shape[1]):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

# Plot random chance
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', linewidth=2, label='Random Chance')

# Customize the plot
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
#plt.show()
plt.savefig('temp_plot.jpeg')  
temp_plot = Image.open('temp_plot.jpeg')
temp_plot.save('roc_auc.jpeg')
temp_plot.close()  
os.remove('temp_plot.jpeg')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 26
#      24 plt.figure(figsize=(12, 8))
#      25 for i in range(y_test.shape[1]):
# ---> 26     plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')
#      28 # Plot random chance
#      29 plt.plot([0, 1], [0, 1], linestyle='--', color='gray', linewidth=2, label='Random Chance')
#
# KeyError: 1

# %% [markdown]
# ### Predicting the direction of penalty shot and comparing with original direction of the shot

# %%
#Dictionary for mapping class_id with the direction of the penalty shot
penalty_dict_test={
    0:'angry',
    1:'happy',
    2:'sad'
}

# %%
from tensorflow.keras.preprocessing import image

# Function to display images and predictions in subplots
def display_images_with_predictions(model):
    # Get the total number of datapoints
    num_datapoints = X_test.shape[0]

    # Select 9 random indices
    random_indices = np.random.choice(num_datapoints, size=15, replace=False)

    # Extract the corresponding datapoints
    selected_datapoints = X_test[random_indices]
    selected_labels = y_test[random_indices]
    # Make predictions
    predictions = model.predict(selected_datapoints)

    # Convert one-hot encoded labels to class indices
    true_labels = np.argmax(selected_labels, axis=1)
    predicted_labels = np.argmax(predictions, axis=1)
    
    # Plot the selected images
    plt.figure(figsize=(40, 20))
    for i in range(len(random_indices)):
        plt.subplot(3, 5, i + 1)
        plt.imshow(selected_datapoints[i])  # Assuming each element in X_test is an image
        plt.title(f'True: {penalty_dict_test[true_labels[i]]}\nPredicted: {penalty_dict_test[predicted_labels[i]]}',fontsize=25)
        plt.axis('off')
        #plt.show()
        plt.savefig('temp_plot.jpeg')  
        temp_plot = Image.open('temp_plot.jpeg')
        temp_plot.save('true_pred.jpeg')
        temp_plot.close()  
        os.remove('temp_plot.jpeg')

# Display images and predictions from valdata
display_images_with_predictions(model)

# %%
model.save('Model_save.h5')

# %% [markdown]
# ## Conclusion:
#
# After training the model(InceptionV3) with fine-tuning the following metric we got:
# 1. Validation_accuracy: 0.9179
# 2. Validation_precision: 0.9179
# 3. Validation_recall: 0.9104
# 4. Validation_auc: 0.9946
# 5. Validation_F1_score: 0.9141
